# %%
import pandas as pd
import numpy as np

copa = pd.read_csv('WorldCups.csv')
copa

copa2 = pd.read_csv('Dades.csv')
copa2
# Out:
#           Jogador  Intervalo    Nação Pos.   Equipe  MP  Inícios  Min.  90s  \
# 0  Olivier Giroud       2022   fr FRA   FW   France   1        1    88  1.0
# 1     Bukayo Saka       2022  eng ENG   FW  England   1        1    69  0.8
# 2    Mehdi Taremi       2022   ir IRN   FW  IR Iran   1        1    90  1.0
# 3   Ferrán Torres       2022   es ESP   FW    Spain   1        1    56  0.6
# 4  Enner Valencia       2022   ec ECU   FW  Ecuador   1        1    76  0.8
# 5    Takuma Asano       2022   jp JPN   FW    Japan   1        0    34  0.4
#
#    Gols  ...   xG  npxG  xAG  npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  \
# 0     2  ...  1.7   1.7  0.1        18   176     13     188     176
# 1     2  ...  0.2   0.2  0.1         3    27     13      40      27
# 2     2  ...  1.0   0.2  0.0         3   103      2     105      24
# 3     2  ...  0.9   0.1  0.0         1   148      0     148      21
# 4     2  ...  1.0   0.2  0.0         2   114      0     114      21
# 5     1  ...  0.3   0.3  0.0         3    79      0      79      79
#
#    npxG+xAG.1     -9999
# 0         188  16ceb862
# 1          40  bc7dc64d
# 2          26  4c2a5d34
# 3          21  9e1035f8
# 4          21  fb485406
# 5          79  13ddc856
#
# [6 rows x 31 columns]

# %%
copa2[["Jogador", "Gols"]].sort_values(by=["Gols"], ascending= False)

# %%
copa["Country"].value_counts().sort_values(ascending=False)
# Out:
# Italy           2
# France          2
# Brazil          2
# Mexico          2
# Germany         2
# Uruguay         1
# Switzerland     1
# Sweden          1
# Chile           1
# England         1
# Argentina       1
# Spain           1
# USA             1
# Korea/Japan     1
# South Africa    1
# Name: Country, dtype: int64

# %%
copa[["Year","MatchesPlayed"]].plot(kind="bar", x = "Year")
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
copa[["Year", "GoalsScored"]].sort_values(by=["GoalsScored"])
# Out:
#     Year  GoalsScored
# 0   1930           70
# 1   1934           70
# 2   1938           84
# 3   1950           88
# 7   1966           89
# 6   1962           89
# 8   1970           95
# 9   1974           97
# 10  1978          102
# 13  1990          115
# 5   1958          126
# 12  1986          132
# 4   1954          140
# 14  1994          141
# 18  2010          145
# 11  1982          146
# 17  2006          147
# 16  2002          161
# 15  1998          171
# 19  2014          171

# %%
copa[["Country", "GoalsScored"]].sort_values(by=["GoalsScored"])
# Out:
#          Country  GoalsScored
# 0        Uruguay           70
# 1          Italy           70
# 2         France           84
# 3         Brazil           88
# 7        England           89
# 6          Chile           89
# 8         Mexico           95
# 9        Germany           97
# 10     Argentina          102
# 13         Italy          115
# 5         Sweden          126
# 12        Mexico          132
# 4    Switzerland          140
# 14           USA          141
# 18  South Africa          145
# 11         Spain          146
# 17       Germany          147
# 16   Korea/Japan          161
# 15        France          171
# 19        Brazil          171

# %%
copa["Winner"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
copa["Runners-Up"].value_counts(ascending=False)
# Out:
# Argentina         3
# Germany FR        3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# Sweden            1
# Germany           1
# France            1
# Name: Runners-Up, dtype: int64

# %%
copa = copa[["Country", "GoalsScored"]]
copa.groupby(["Country"]).sum().sort_values(by="GoalsScored", ascending= True)
# Out:
#               GoalsScored
# Country
# Uruguay                70
# Chile                  89
# England                89
# Argentina             102
# Sweden                126
# Switzerland           140
# USA                   141
# South Africa          145
# Spain                 146
# Korea/Japan           161
# Italy                 185
# Mexico                227
# Germany               244
# France                255
# Brazil                259

# %%
copa["Winner"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\T-Gamer\Documents\Desenvolvimento 2022\Analise_Copa\Copa.ipynb Célula: 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/T-Gamer/Documents/Desenvolvimento%202022/Analise_Copa/Copa.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> copa["Winner"].value_counts()
#
# File c:\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Winner'

# %%
copa["Winner"].value_counts().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\T-Gamer\Documents\Desenvolvimento 2022\Analise_Copa\Copa.ipynb Célula: 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/T-Gamer/Documents/Desenvolvimento%202022/Analise_Copa/Copa.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> copa["Winner"].value_counts().plot(kind="bar")
#
# File c:\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Winner'
